# %% [markdown]
# <a id="2"></a>
# <div style="display: flex; align-items: center; justify-content: center; text-align:center; border-radius:20px; padding:30px; color:white; margin:0 auto; font-size:500%; font-family:Arial; background-color:brown; overflow:hidden; width: 500px; height: 250px;
#     box-shadow: 0 0 700px 10px rgba(5, 5, 5, 5.0);">
#     <b>Social Media Analysis</b>
# </div>

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:brown; overflow:hidden"><b>  ✨ **About Author** ✨ </b></div>
#
# <div style="background-color: white; border: 9px solid brown; border-radius: 19px; box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1); max-width: 600px; margin: 20px auto; padding: 20px; text-align: center; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;">
#     <h2 style="color: black; font-weight: bold; margin-bottom: 10px;">WAQAR ALI</h2>
#     <p style="font-size: 16px; line-height: 1.6; color: black; margin-bottom: 20px;">
#         I'm a passionate Data Scientist and Analyst, dedicated to transforming raw data into actionable insights through captivating visualizations. Let's dive into the fascinating world of data and uncover the stories hidden within! 📊🔍✨
#     </p>
#     <p style="color: black; font-size: 16px; font-weight: bold;">Connect with me:</p>
#     <a href="https://www.linkedin.com/in/waqar-ali-a51297318/" target="_blank" style="display: inline-block; background-color: purple; color: white; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">LinkedIn</a>
#     <a href="https://github.com/waqi786" target="_blank" style="display: inline-block; background-color: green; color: white; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">GitHub</a>
#     <a href="https://www.kaggle.com/waqi786" target="_blank" style="display: inline-block; background-color: red; color: white; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">Kaggle</a>
#     <a href="mailto:dsali20838@gmail.com" style="display: inline-block; background-color: blue; color: white; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">Email</a>
# </div>

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:brown; overflow:hidden"><b> ✨ Import Libraries ✨</b></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:brown; overflow:hidden"><b> ✨ Load Data ✨</b></div>

# %%
df = pd.read_csv("/kaggle/input/social-media-analysis/social-media.csv")
df.head(10)
# Out:
#    UserId  UsageDuraiton  Age       Country  TotalLikes
# 0       1              2   55        Turkey           5
# 1       2              6   45        Canada          10
# 2       3              3   50       Ireland           7
# 3       4              4   35  South Africa           5
# 4       5              1   58        Turkey           2
# 5       6             13   18        Turkey          25
# 6       7              3   50     Australia           1
# 7       8              9   25        Canada           8
# 8       9              8   27        Kosovo          10
# 9      10              9   26     Australia           0

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:brown; overflow:hidden"><b> ✨ Data Analysis & Visualization ✨</b></div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UserId         63 non-null     int64
#  1   UsageDuraiton  63 non-null     int64
#  2   Age            63 non-null     int64
#  3   Country        63 non-null     object
#  4   TotalLikes     63 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.6+ KB

# %%
df.shape
# Out:
# (63, 5)

# %%
df.describe()
# Out:
#           UserId  UsageDuraiton        Age  TotalLikes
# count  63.000000      63.000000  63.000000   63.000000
# mean   31.761905       4.000000  33.777778    5.317460
# std    18.015866       2.879292  15.540213    6.135106
# min     1.000000       1.000000  18.000000    0.000000
# 25%    16.500000       2.000000  19.000000    1.500000
# 50%    32.000000       3.000000  26.000000    4.000000
# 75%    47.500000       5.000000  50.000000    6.000000
# max    62.000000      13.000000  60.000000   28.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# UserId           0
# UsageDuraiton    0
# Age              0
# Country          0
# TotalLikes       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['UserId', 'UsageDuraiton', 'Age', 'Country', 'TotalLikes'], dtype='object')

# %%
plt.figure(figsize = (10,4))
a = sns.countplot(x = 'Age', data = df)
plt.title("Age")
# Out:
# Text(0.5, 1.0, 'Age')

# %%
plt.figure(figsize = (15,7))
a = sns.countplot(x = 'Country', data = df)
plt.title("Country")
# Out:
# Text(0.5, 1.0, 'Country')

# %%
plt.figure(figsize = (15,7))
a = sns.countplot(x = 'TotalLikes', data = df)
plt.title("Total Likes")
# Out:
# Text(0.5, 1.0, 'Total Likes')

# %%
plt.figure(figsize = (15,7))
a = sns.countplot(x = 'UsageDuraiton', data = df)
plt.title("Usage Duration")
# Out:
# Text(0.5, 1.0, 'Usage Duration')

# %%
d = df.groupby(['Country'],as_index = False)['Age'].count().sort_values(by='Age', ascending = False)
sns.barplot(x = 'Age', y = 'Country', data = d)
# Out:
# <Axes: xlabel='Age', ylabel='Country'>

# %%
c = df.groupby(['UsageDuraiton'], as_index=False)['Age'].count().sort_values(by='Age', ascending=False)
sns.barplot(x='Age', y='UsageDuraiton', data=c)
# Out:
# <Axes: xlabel='Age', ylabel='UsageDuraiton'>

# %%
b =df.groupby(['Country'], as_index=False)['TotalLikes'].count().sort_values(by='TotalLikes', ascending=False)
sns.barplot(x='TotalLikes', y='Country', data=b)
# Out:
# <Axes: xlabel='TotalLikes', ylabel='Country'>

# %%
# Correct the spelling of 'UsageDuration'
v = df.groupby(['UsageDuraiton', 'Country'], as_index=False)['Age'].count().sort_values(by='Age', ascending=False)

# Plotting correctly with 'UsageDuration' and 'Country'
sns.catplot(x='Age', y='UsageDuraiton', hue='Country', data=v)
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:brown; overflow:hidden"><b> ✨ Summary ✨ </b></div>

# %% [markdown]
# # 1. **Introduction:**
# This analysis examines user engagement based on age, country, and interactions (total likes) using a dataset with 5 columns: UserId, UsageDuraiton, Age, Country, and TotalLikes.
#
# # 2. **Data Cleaning:**
# Handled missing values, corrected data types, and removed outliers from Age and UsageDuration.
#
# # 3. **Key Insights:**
#
# **Age Distribution:** The most common age in the dataset is 18, followed by 55, 50, 26, 19, and 20. This indicates that the user base is spread across a wide age range, with a notable concentration of younger (18-26) and older (50-55) individuals.
#
# **Likes:** Younger users (18–25) and old age (50-55) receive more likes on average.
#
# **Country Engagement:** Users from the Turkey and Singapore have the highest UsageDuration.
#
# # 4. **Conclusion:**
# The analysis shows that both younger (18-26) and older (50-55) users are highly engaged, with significant interactions in terms of likes. Additionally, users from Turkey and Singapore exhibit the longest usage durations, indicating stronger engagement from these regions.

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:brown; overflow:hidden"><b> ✨ Thank You ✨</b></div>
